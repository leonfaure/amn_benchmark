# %%
import scipy.io
mat = scipy.io.loadmat('mtbpromdata.mat')

# %%
mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'regulator', 'model', 'expression', 'targets', 'expressionid', 'litevidence', 'prob_prior'])

# %%
regulator_data = mat['regulator']
model_data = mat['model']
expression_data = mat['expression']
targets_data = mat['targets']
expressionid_data = mat['expressionid']
litevidence_data = mat['litevidence']
prob_prior_data = mat['prob_prior']

# %%
regulator_data.shape, model_data.shape, expression_data.shape, targets_data.shape, expressionid_data.shape, litevidence_data.shape, prob_prior_data.shape
# Out:
# ((218, 1), (1, 1), (4320, 437), (218, 1), (4320, 1), (218, 1), (218, 1))

# %%
import numpy as np
expressionid_list = expressionid_data.tolist()
expressionid_list = [x[0][0] for x in expressionid_list]
expressionid_list
# Out:
# ['Rv0001',
#  'Rv0002',
#  'Rv0003',
#  'ORF187_in_recF_region',
#  'Rv0005',
#  'Rv0006',
#  'Rv0007',
#  'Rv0008c',
#  'Rv0009',
#  'Rv0010c',
#  'Rv0011c',
#  'Rv0012',
#  'Rv0013',
#  'Rv0014c',
#  'Rv0015c',
#  'Rv0016c',
#  'Rv0017c',
#  'Rv0018c',
#  'Rv0019c',
#  'Rv0020c',
#  'Rv0021c',
#  'Rv0022c',
#  'Rv0023',
#  'Rv0024',
#  'Rv0025',
#  'Rv0026',
#  'Rv0027',
#  'Rv0028',
#  'Rv0029',
#  'Rv0030',
#  'Rv0031',
#  'Rv0032',
#  'Rv0033',
#  'Rv0034',
#  'Rv0035',
#  'Rv0036c',
#  'Rv0037c',
#  'Rv0038',
#  'Rv0039c',
#  'Rv0040c',
#  'Rv0041',
#  'Rv0042c',
#  'Rv0043c',
#  'Rv0044c',
#  'Rv0045c',
#  'Rv0046c',
#  'Rv0047c',
#  'Rv0048c',
#  'Rv0049',
#  'Rv0050',
#  'Rv0051',
#  'Rv0052',
#  'Rv0053',
#  'Rv0054',
#  'Rv0055',
#  'Rv0056',
#  'Rv0057',
#  'Rv0058',
#  'Rv0059',
#  'Rv0060',
#  'Rv0061',
#  'Rv0062',
#  'Rv0063',
#  'Rv0064',
#  'Rv0065',
#  'Rv0066c',
#  'Rv0067c',
#  'Rv0068',
#  'Rv0069c',
#  'Rv0070c',
#  'Rv0071',
#  'Rv0072',
#  'Rv0073',
# ...
