# %%
import pyreadr

# You can find information on which table contains which data, in the file 'CoRegFlux/R/data.R'

GRN_data = pyreadr.read_r('CoRegFlux/data/SC_EXP_DATA.rda')['SC_EXP_DATA'] # for computing GRN
aliases = pyreadr.read_r("CoRegFlux/data/aliases_SC.rda")['aliases_SC'] # correspondance table between gene name in GRN and metabolic model
all_data = pyreadr.read_r('CoRegFlux/data/SC_Test_data.rda')['SC_Test_data'] #

# %%
all_data
# Out:
#           yB8n055.03II01.batch.p1  yB8n056.03II01.batch.p2  \
# rownames
# ANT1                      -0.5500                    -0.15
# IXR1                      -0.8700                    -0.39
# DAN1                      -0.3700                    -0.89
# FIG4                      -0.1872                    -0.29
# CAJ1                       0.2300                     1.28
# ...                           ...                      ...
# CIC1                       0.3900                     0.04
# HO                         0.2300                    -0.23
# YDR360W                    0.3700                    -0.33
# YDR278C                    0.3800                    -1.01
# ERG5                      -0.8000                    -0.96
#
#           yB8n057.03II01.batch.p3  yB8n058.03II01.batch.p4  \
# rownames
# ANT1                        -0.70                   -0.520
# IXR1                        -0.34                   -0.435
# ...

# %%
aliases
# Out:
#      geneName_model geneName_GRN
# 0           YMR056C         AAC1
# 1           YBR085W         AAC3
# 2           YJR155W        AAD10
# 3           YNL331C        AAD14
# 4           YDL243C         AAD4
# ...             ...          ...
# 5516        YBR287W         ZSP1
# 5517        YBR046C         ZTA1
# 5518        YGR285C         ZUO1
# 5519        YNL241C         ZWF1
# 5520        YLR303W        MET15
#
# [5521 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.close("all")
sns.set_theme()
sns.histplot(all_data.iloc[:,4:10], bins=10, multiple="dodge")
plt.show()
